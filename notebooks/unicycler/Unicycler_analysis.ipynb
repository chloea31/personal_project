# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
illumina_f = pd.read_csv("../../reports/unicycler/QC/illumina_f_fastqc/illumina_f_fastqc/fastqc_data.txt",sep = '\t', skiprows = 13)
illumina_f.info()
illumina_f.head() # 58
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688 entries, 0 to 687
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   #Base            688 non-null    object
#  1   Mean             678 non-null    object
#  2   Median           407 non-null    object
#  3   Lower Quartile   174 non-null    object
#  4   Upper Quartile   174 non-null    object
#  5   10th Percentile  115 non-null    object
#  6   90th Percentile  115 non-null    object
# dtypes: object(7)
# memory usage: 37.8+ KB
#   #Base       Mean Median Lower Quartile Upper Quartile 10th Percentile  \
# 0     1  33.308903   34.0           33.0           34.0            32.0
# 1     2  33.453257   34.0           33.0           34.0            32.0
# 2     3  33.517042   34.0           33.0           34.0            32.0
# 3     4  33.530069   34.0           33.0           34.0            32.0
# ...

# %%
illumina_f.loc[100:]["#Base"]
# Out:
# 100            1101
# 101            1101
# 102            1101
# 103            1101
# 104            1101
#            ...
# 683         225-229
# 684         230-234
# 685         235-239
# 686             240
# 687    >>END_MODULE
# Name: #Base, Length: 588, dtype: object

# %%
#illumina_f(illumina_f[illumina_f["#Base"] != str(">>END_MODULE")] & illumina_f[illumina_f["#Base"] != str(1101)])
illumina_f.head(58)
# Out:
#       #Base                Mean Median Lower Quartile Upper Quartile  \
# 0         1           33.308903   34.0           33.0           34.0
# 1         2           33.453257   34.0           33.0           34.0
# 2         3           33.517042   34.0           33.0           34.0
# 3         4           33.530069   34.0           33.0           34.0
# 4         5            33.39641   34.0           33.0           34.0
# 5         6           35.554352   37.0           34.0           37.0
# 6         7           35.514425   37.0           34.0           37.0
# 7         8           35.437793   37.0           34.0           37.0
# 8         9           35.413043   37.0           34.0           37.0
# 9     10-14           36.212192   37.4           35.6           37.4
# 10    15-19          37.5116424   38.0           38.0           38.0
# 11    20-24          37.7257354   38.4           38.0           38.4
# 12    25-29          38.0308534   39.0           38.0           39.0
# ...

# %%
# Parsing the file
# def parsing_file(file):
#     file2 = file.loc[">>END_MODULE":, :]
#     #print("============================")
#     print(file2)
#     return file2
# parsing_file(illumina_f)
illumina_f["#Base"]
# Out:
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
#            ...
# 683         225-229
# 684         230-234
# 685         235-239
# 686             240
# 687    >>END_MODULE
# Name: #Base, Length: 688, dtype: object

# %%
fig = px.histogram(illumina_f["#Base"], x = "#Base")
fig.show()
